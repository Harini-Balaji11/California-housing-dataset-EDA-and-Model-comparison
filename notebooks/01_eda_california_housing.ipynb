# %% [markdown]
# # California Housing — EDA
#
# This notebook presents a concise, polished EDA for the California Housing dataset and mirrors the figures generated by `scripts/run_eda.py`. Run all cells top-to-bottom to reproduce plots into `../reports/figures/`.

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# Output directory
figures_dir = Path("../reports/figures")
figures_dir.mkdir(parents=True, exist_ok=True)

# Load data
cal = fetch_california_housing(as_frame=True)
df = cal.frame

df.head()

# %%
# Target distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['MedHouseVal'], kde=True, bins=30, color='crimson')
plt.title('Distribution of Median House Value')
plt.xlabel('Median House Value ($100,000s)')
plt.tight_layout()
plt.savefig(figures_dir / 'target_hist.png', dpi=150)
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(9, 7))
ax = sns.heatmap(df.corr(numeric_only=True), annot=False, cmap='coolwarm', center=0)
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.savefig(figures_dir / 'correlation_heatmap.png', dpi=150)
plt.show()

# %%
# Geospatial scatter by value
plt.figure(figsize=(8, 6))
sc = plt.scatter(df['Longitude'], df['Latitude'], c=df['MedHouseVal'], cmap='viridis', s=8, alpha=0.6)
plt.colorbar(sc, label='MedHouseVal ($100,000s)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('California Housing: Geo Scatter by Median Value')
plt.tight_layout()
plt.savefig(figures_dir / 'geo_scatter.png', dpi=150)
plt.show()
